# %% [markdown]
# # EDA of the 10-K filings of Microsoft, Apple, and Tesla (2023-2025)

# %%
#import dependencies
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
# %pip install html5lib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#file to df
df1 = pd.read_csv("apple_10k_financials_2023_2025.csv")
df2 = pd.read_csv("microsoft_10k_financials_2023_2025.csv")
df3 = pd.read_csv("tesla_10k_financials_2023_2025.csv")

# %%
df1
# Out:
#   company  fiscal_year  period_end  \
# 0   Apple         2023  2023-09-30
# 1   Apple         2024  2024-09-28
# 2   Apple         2025  2025-09-27
#
#                                           filing_url  total_revenue_musd  \
# 0  https://www.sec.gov/Archives/edgar/data/320193...              383285
# 1  https://www.sec.gov/Archives/edgar/data/320193...              391035
# 2  https://www.sec.gov/Archives/edgar/data/320193...              416161
#
#    net_income_musd  total_assets_musd  total_liabilities_musd  \
# 0            96995             352583                  290437
# 1            93736             364980                  308030
# 2           112010             359241                  285508
#
#    cash_flow_from_operating_activities_musd
# 0                                    110543
# 1                                    118254
# 2                                    111482

# %%
df2
# Out:
#      company  fiscal_year  period_end  \
# 0  Microsoft         2023  2023-06-30
# 1  Microsoft         2024  2024-06-30
# 2  Microsoft         2025  2025-06-30
#
#                                           filing_url  total_revenue_musd  \
# 0  https://www.sec.gov/Archives/edgar/data/789019...              211915
# 1  https://www.sec.gov/Archives/edgar/data/789019...              245122
# 2  https://www.sec.gov/Archives/edgar/data/789019...              281724
#
#    net_income_musd  total_assets_musd  total_liabilities_musd  \
# 0            72361             411976                  205753
# 1            88136             512163                  243686
# 2           101832             619003                  275524
#
#    cash_flow_from_operating_activities_musd
# 0                                     87582
# 1                                    118548
# 2                                    136162

# %%
df3
# Out:
#   company  fiscal_year  period_end  \
# 0   Tesla         2023  2023-12-31
# 1   Tesla         2024  2024-12-31
# 2   Tesla         2025  2025-12-31
#
#                                           filing_url  total_revenue_musd  \
# 0  https://www.sec.gov/Archives/edgar/data/131860...               96773
# 1  https://www.sec.gov/Archives/edgar/data/131860...               97690
# 2  https://www.sec.gov/Archives/edgar/data/131860...               94830
#
#    net_income_musd  total_assets_musd  total_liabilities_musd  \
# 0            14999             106618                   44318
# 1             7147             122070                   49157
# 2             3790             135000                   52863
#
#    cash_flow_from_operating_activities_musd
# 0                                     13256
# 1                                     14923
# 2                                     14747
